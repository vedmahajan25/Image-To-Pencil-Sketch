# %%
pip install opencv-python
# Out:
# ...
#      ---------------------------------------- 38.2/38.2 MB 9.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
kl = cv2.imread("lambo.jpg")
kl = cv2.cvtColor(kl,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(kl)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
kls = cv2.cvtColor(kl, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(kls,cmap="gray")
plt.axis("off")
plt.title("Image to GrayScale Image ")
plt.show()

# %%
imk = cv2.bitwise_not(kls)
plt.figure(figsize=(8,8))
plt.imshow(imk,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %%
ims = cv2.GaussianBlur(imk, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(ims,cmap="gray")
plt.axis("off")
plt.title("Smoothened Image")
plt.show()

# %%
vr = cv2.divide(kls, 255 - ims, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(vr,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %%
#final sketch output

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,5,1)
plt.imshow(kl)
plt.axis("off")
plt.title("Original Image")
plt.subplot(1,5,2)
plt.imshow(kls,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.subplot(1,5,3)
plt.imshow(imk,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.subplot(1,5,4)
plt.imshow(ims,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.subplot(1,5,5)
plt.imshow(vr,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %%
# thank you
